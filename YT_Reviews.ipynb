# %%
# !pip install youtube-comment-downloader
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 10.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# Now you can use the following code to download comments. Replace the `video_url` with the URL of the YouTube video you want to get comments from.

# %%
from youtube_comment_downloader import YoutubeCommentDownloader
import pandas as pd

downloader = YoutubeCommentDownloader()

# List of YouTube video URLs
video_urls = [
    #The good doctor
    # "https://www.youtube.com/watch?v=dxaufulNs7Y",
    # "https://www.youtube.com/watch?v=aM9bZqyeX8c",
    # "https://www.youtube.com/watch?v=w8hRQh3VGOQ",
    # "https://www.youtube.com/watch?v=WA9B4_e6sS0",
    # "https://www.youtube.com/watch?v=lQKYnJI4XWU",
    # "https://www.youtube.com/watch?v=UOoF9pXx4hs",
    # "https://www.youtube.com/watch?v=Ya_trIAWIXA",
    # "https://www.youtube.com/watch?v=esVfOevhx9s",
    # "https://www.youtube.com/watch?v=EKxEKJvvPig",
    # "https://www.youtube.com/watch?v=IhHGNmJMbjE",
    # "https://www.youtube.com/watch?v=bIfL_bcTGQY",
    # "https://www.youtube.com/watch?v=MpagDtx1oTA",
    # "https://www.youtube.com/watch?v=YT3qoDjynDk",
    # "https://www.youtube.com/watch?v=8byiwOY5XM0",
    # "https://www.youtube.com/watch?v=St849qlZY5g",
    # "https://www.youtube.com/watch?v=YGY3sdktP2Y",
    # "https://www.youtube.com/watch?v=jOTiCA_iChE",
    # "https://www.youtube.com/watch?v=6fLESDIpedw"



]

movie_videos = {
    "Front of the class": "https://www.youtube.com/watch?v=EsPTGIW_hGQ", #2235 comments
    "Front of the class": "https://www.youtube.com/watch?v=Evy1tEPYacw", #125 comments
    "Music": "https://www.youtube.com/watch?v=138y6mtgll8", #5201 comments
    "Music": "https://www.youtube.com/watch?v=Yx66GgYpTsA", #4999 comments
    "Taare Zameen Par": "https://www.youtube.com/watch?v=2DVNQVVoj9w",#520 comments
    "Taare Zameen Par": "https://www.youtube.com/watch?v=2LEyl7GGU38",#464 comments
    "Taare Zameen Par": "https://www.youtube.com/watch?v=2LEyl7GGU38",#464 comments
    "Temple Gradin": "https://www.youtube.com/watch?v=T5TtoH28tsE",#390 comments
    "Temple Gradin": "https://www.youtube.com/watch?v=cpkN0JdXRpM", #563 comments
    "Temple Gradin": "https://www.youtube.com/watch?v=MvWKKDG55YA", #563 comments
    "Temple Gradin": "https://www.youtube.com/watch?v=UU-80Vr8xug" #563 comments
    #https://www.youtube.com/watch?v=bZamcu-Q75Y. speech by temple grandin
}

all_comments = []

for url in video_urls:
    try:
        comments = downloader.get_comments_from_url(url, sort_by=1)
        for comment in comments:
            all_comments.append({
                "video_url": url,
                "comment_text": comment['text']
            })
        print(f"✔ Collected comments from {url}")
    except Exception as e:
        print(f"⚠ Error fetching {url}: {e}")

# Create a single DataFrame
comments_df = pd.DataFrame(all_comments)

# Save to Excel
comments_df.to_excel("youtube_comments.xlsx", index=False)

print("✅ All comments saved to 'youtube_comments.xlsx'")
comments_df.head()
# Out:
# ✔ Collected comments from https://www.youtube.com/watch?v=dxaufulNs7Y
# ✔ Collected comments from https://www.youtube.com/watch?v=aM9bZqyeX8c
# ✔ Collected comments from https://www.youtube.com/watch?v=w8hRQh3VGOQ
# ✔ Collected comments from https://www.youtube.com/watch?v=WA9B4_e6sS0
# ✔ Collected comments from https://www.youtube.com/watch?v=lQKYnJI4XWU
# ✔ Collected comments from https://www.youtube.com/watch?v=UOoF9pXx4hs
# ✔ Collected comments from https://www.youtube.com/watch?v=Ya_trIAWIXA
# ✔ Collected comments from https://www.youtube.com/watch?v=esVfOevhx9s
# ✔ Collected comments from https://www.youtube.com/watch?v=EKxEKJvvPig
# ✔ Collected comments from https://www.youtube.com/watch?v=IhHGNmJMbjE
# ✔ Collected comments from https://www.youtube.com/watch?v=bIfL_bcTGQY
# ✔ Collected comments from https://www.youtube.com/watch?v=MpagDtx1oTA
# ✔ Collected comments from https://www.youtube.com/watch?v=YT3qoDjynDk
# ...

# %%
# Save the DataFrame to an XLSX file
comments_df.to_excel("youtube_comments.xlsx", index=False)

print("DataFrame 'comments_df' has been saved to 'youtube_comments.xlsx'")

from google.colab import files

files.download('youtube_comments.xlsx')
# Out:
# DataFrame 'comments_df' has been saved to 'youtube_comments.xlsx'

# %%
from youtube_comment_downloader import YoutubeCommentDownloader
import pandas as pd

# Initialize downloader
downloader = YoutubeCommentDownloader()

# Dictionary of movies with YouTube URLs
movie_videos = {
    "Atypical (Netflix Series)": [
        "https://www.youtube.com/watch?v=ieHh4U-QYwU"
    ],
    "The Good Doctor (ABC Series)": [
        "https://www.youtube.com/watch?v=XD6Vp0mhkNs",
        "https://www.youtube.com/watch?v=3om3dY_50nQ",
        "https://www.youtube.com/watch?v=A8KXO03Ox1k",
        "https://www.youtube.com/watch?v=_6L7YMgLrqg",
        "https://www.youtube.com/watch?v=tyXcoH6Vjeg"
    ],
    "Temple Grandin (HBO Movie)": [
        "https://www.youtube.com/watch?v=cpkN0JdXRpM",
        "https://www.youtube.com/watch?v=T5TtoH28tsE",
        "https://www.youtube.com/watch?v=cpkN0JdXRpM",
        "https://www.youtube.com/watch?v=UU-80Vr8xug",
        "https://www.youtube.com/watch?v=MvWKKDG55YA"
    ],
    "Everything's Gonna Be Okay (Freeform Series)": [
        "https://www.youtube.com/watch?v=NHdmcU2vmMQ",
        "https://www.youtube.com/watch?v=pyt_e50eoeI",
        "https://www.youtube.com/watch?v=XQZmd7GBGrI",
        "https://www.youtube.com/watch?v=eRQaPI7b7mc",
        "https://www.youtube.com/watch?v=2CGj-ETHAoM"
    ],
    "Taare Zameen Par (Bollywood Film)": [
        "https://www.youtube.com/watch?v=3Vn0SOzTmEI&list=RD3Vn0SOzTmEI&start_radio=1",
        "https://www.youtube.com/watch?v=tn_2Ie_jtX8"
    ],
    "Sitare Zameen Par (Bollywood Film)": [
        "https://www.youtube.com/watch?v=YH6k5weqwy8&t=16s"
    ],
    "Front of the Class (Hallmark Movie)": [
        "https://www.youtube.com/watch?v=hJDidwZ2_Wo",
        "https://www.youtube.com/watch?v=Evy1tEPYacw&t=18s"
    ],
    "The Tic Code (1998 Film)": [],
    "Patience (2017 Film)": [
        "https://www.youtube.com/watch?v=KvB1QHjVjVI",
        "https://www.youtube.com/watch?v=XdCaSy2Ln1g"
    ],
    "Barfi! (Bollywood Film)": [
        "https://www.youtube.com/watch?v=tEufn51wu78&t=675s"
    ],
    "My Name is Khan (Bollywood Film)": [
        "https://www.youtube.com/watch?v=nqxgYT3TYzY",
        "https://www.youtube.com/watch?v=XAtPpjEZwC8",
        "https://www.youtube.com/watch?v=ScqUYSNe6Gs"
    ],
    "Music (Sia Film)": [
        "https://www.youtube.com/watch?v=yLBl3he3Nqg&t=39s",
        "https://www.youtube.com/watch?v=T3hxL41mVbU"
    ],
    "Hichki (Bollywood Film)": [
        "https://www.youtube.com/watch?v=nLSaCFlXn-g"
    ],
    "Rain Man (1988 Film)": [
        "https://www.youtube.com/watch?v=mlNwXuHUA8I",
        "https://www.youtube.com/watch?v=vk7eA4gVDno&t=137s"
    ],
    "Koi Mil Gaya (Bollywood Film)": [
        "https://www.youtube.com/watch?v=IBpZH-CFgZ0&t=4s"
    ],
    "Extraordinary Attorney Woo (Korean Series)": [
        "https://www.youtube.com/watch?v=MxeXECe2t-c",
        "https://www.youtube.com/watch?v=7va8qSF7QP8"
    ]
}


# Neurodivergence-related terms (case-insensitive)
neuro_terms = [
    "autism", "autistic", "neurodivergent", "asperger", "adhd", "tourette", "spectrum",
    "dyslexia", "dyspraxia", "ocd", "ocd tendencies", "sensory processing disorder",
    "spd", "executive dysfunction", "hyperactivity", "stimming", "self-stimulating",
    "neurodiverse", "learning disability", "learning difference", "social communication disorder",
    "processing disorder", "attention deficit", "autism spectrum disorder", "asd",
    "neurodivergence", "neurological difference", "neurodevelopmental", "special needs",
    "social anxiety", "sensory sensitivity", "developmental disorder", "mental difference",
    "cognitive difference"
]


all_comments = []

# Loop through movies and URLs
for movie_name, urls in movie_videos.items():
    for url in urls:
        try:
            # Fetch comments (top comments first)
            comments = downloader.get_comments_from_url(url, sort_by=1)
            for comment in comments:
                text_lower = comment['text'].lower()
                # Check if comment contains any neurodivergent-related terms
                if any(term.lower() in text_lower for term in neuro_terms):
                    all_comments.append({
                        "url": url,
                        "movie": movie_name,
                        "source": "YouTube Comments",
                        "review": comment['text']
                    })
            print(f"✔ Collected filtered comments for {movie_name} ({url})")
        except Exception as e:
            print(f"⚠ Error fetching {movie_name} ({url}): {e}")

# Create a DataFrame
comments_df = pd.DataFrame(all_comments)

# Save to Excel
comments_df.to_excel("youtube_comments_filtered.xlsx", index=False)

print("✅ All filtered comments saved to 'youtube_comments_filtered.xlsx'")
print(comments_df.head())
# Out:
# ✔ Collected filtered comments for Atypical (Netflix Series) (https://www.youtube.com/watch?v=ieHh4U-QYwU)
# ✔ Collected filtered comments for The Good Doctor (ABC Series) (https://www.youtube.com/watch?v=XD6Vp0mhkNs)
# ✔ Collected filtered comments for The Good Doctor (ABC Series) (https://www.youtube.com/watch?v=3om3dY_50nQ)
# ✔ Collected filtered comments for The Good Doctor (ABC Series) (https://www.youtube.com/watch?v=A8KXO03Ox1k)
# ✔ Collected filtered comments for The Good Doctor (ABC Series) (https://www.youtube.com/watch?v=_6L7YMgLrqg)
# ✔ Collected filtered comments for The Good Doctor (ABC Series) (https://www.youtube.com/watch?v=tyXcoH6Vjeg)
# ✔ Collected filtered comments for Temple Grandin (HBO Movie) (https://www.youtube.com/watch?v=cpkN0JdXRpM)
# ✔ Collected filtered comments for Temple Grandin (HBO Movie) (https://www.youtube.com/watch?v=T5TtoH28tsE)
# ✔ Collected filtered comments for Temple Grandin (HBO Movie) (https://www.youtube.com/watch?v=cpkN0JdXRpM)
# ...

# %%
# Save the DataFrame to an XLSX file
comments_df.to_excel("youtube_comments.xlsx", index=False)

print("DataFrame 'comments_df' has been saved to 'youtube_comments.xlsx'")

from google.colab import files

files.download('youtube_comments_filtered.xlsx')
# Out:
# DataFrame 'comments_df' has been saved to 'youtube_comments.xlsx'
